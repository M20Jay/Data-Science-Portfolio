# %% [markdown]
# <a href="https://colab.research.google.com/github/M20Jay/Data-Science-Portfolio/blob/main/Quantitative_Work.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# importing libraries
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# %%
# loading the loan dataset
path = "/content/drive/MyDrive/Python Dataset/Datasets/Loan_Approval_Dataset.xlsx"

# %%
df = pd.read_excel(path)

# %%
df.head()
# Out:
#    loan_id   no_of_dependents      education  self_employed   income_annum  \
# 0        1                  2       Graduate             No      9600000.0
# 1        2                  0   Not Graduate            Yes      4100000.0
# 2        3                  3       Graduate             No      9100000.0
# 3        4                  3       Graduate             No      8200000.0
# 4        5                  5   Not Graduate            Yes      9800000.0
#
#     loan_amount   loan_term   cibil_score   residential_assets_value  \
# 0    29900000.0        12.0         778.0                  2400000.0
# 1    12200000.0         8.0         417.0                  2700000.0
# 2    29700000.0        20.0         506.0                  7100000.0
# 3    30700000.0         8.0         467.0                 18200000.0
# 4    24200000.0        20.0         382.0                 12400000.0
#
#     commercial_assets_value   luxury_assets_value   bank_asset_value  \
# ...

# %%
# Explore the type of data present in each of the columns

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3699 entries, 0 to 3698
# Data columns (total 13 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   loan_id                    3699 non-null   int64
#  1    no_of_dependents          3699 non-null   int64
#  2    education                 3699 non-null   object
#  3    self_employed             3699 non-null   object
#  4    income_annum              3685 non-null   float64
#  5    loan_amount               3682 non-null   float64
#  6    loan_term                 3692 non-null   float64
#  7    cibil_score               3690 non-null   float64
#  8    residential_assets_value  3682 non-null   float64
#  9    commercial_assets_value   3684 non-null   float64
#  10   luxury_assets_value       3692 non-null   float64
#  11   bank_asset_value          3688 non-null   float64
#  12   loan_status               3699 non-null   object
# ...

# %%
df.describe()
# Out:
#            loan_id   no_of_dependents   income_annum   loan_amount  \
# count  3699.000000        3699.000000   3.685000e+03  3.682000e+03
# mean   1850.000000           2.504731   5.035658e+06  1.505062e+07
# std    1067.953651           1.696293   2.801881e+06  9.025826e+06
# min       1.000000           0.000000   2.000000e+05  3.000000e+05
# 25%     925.500000           1.000000   2.600000e+06  7.700000e+06
# 50%    1850.000000           3.000000   5.000000e+06  1.450000e+07
# 75%    2774.500000           4.000000   7.500000e+06  2.130000e+07
# max    3699.000000           5.000000   9.900000e+06  3.950000e+07
#
#          loan_term   cibil_score   residential_assets_value  \
# count  3692.000000   3690.000000               3.682000e+03
# mean     10.847237    598.047154               7.379441e+06
# std       5.711331    172.198696               6.438633e+06
# min       2.000000    300.000000              -1.000000e+05
# ...

# %%
df.describe().T
# Out:
#                             count          mean           std       min  \
# loan_id                    3699.0  1.850000e+03  1.067954e+03       1.0
#  no_of_dependents          3699.0  2.504731e+00  1.696293e+00       0.0
#  income_annum              3685.0  5.035658e+06  2.801881e+06  200000.0
#  loan_amount               3682.0  1.505062e+07  9.025826e+06  300000.0
#  loan_term                 3692.0  1.084724e+01  5.711331e+00       2.0
#  cibil_score               3690.0  5.980472e+02  1.721987e+02     300.0
#  residential_assets_value  3682.0  7.379441e+06  6.438633e+06 -100000.0
#  commercial_assets_value   3684.0  4.935749e+06  4.372724e+06       0.0
#  luxury_assets_value       3692.0  1.505257e+07  9.069968e+06  300000.0
#  bank_asset_value          3688.0  4.970933e+06  3.254849e+06       0.0
#
#                                  25%         50%         75%         max
# loan_id                        925.5      1850.0      2774.5      3699.0
# ...

# %%
 # Exploring the shape of the data
 df.shape
# Out:
# (3699, 13)

# %%
#checking the number of null values in the dataset columns wise
df.isnull().sum()
# Out:
# loan_id                       0
#  no_of_dependents             0
#  education                    0
#  self_employed                0
#  income_annum                14
#  loan_amount                 17
#  loan_term                    7
#  cibil_score                  9
#  residential_assets_value    17
#  commercial_assets_value     15
#  luxury_assets_value          7
#  bank_asset_value            11
#  loan_status                  0
# dtype: int64

# %%
# Dropping Loan_ID column
df.drop(['loan_id'],axis=1,inplace=True)

# %%
# checking the number of unique elements in our dataset
df.nunique()
# Out:
#  no_of_dependents              6
#  education                     2
#  self_employed                 2
#  income_annum                 98
#  loan_amount                 377
#  loan_term                    10
#  cibil_score                 601
#  residential_assets_value    273
#  commercial_assets_value     188
#  luxury_assets_value         375
#  bank_asset_value            146
#  loan_status                   2
# dtype: int64

# %%
#  Checking correlation analysis between variables
plt.figure(figsize=(12,6))

sns.heatmap(df.corr(),cmap='BrBG',fmt='.2f',
            linewidths=2,annot=True)
# Out:
# <ipython-input-89-93f718a75391>:4: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(df.corr(),cmap='BrBG',fmt='.2f',
# <Axes: >

# %%
# As all the categorical values are binary so we can use Label Encoder for all such columns and the values will change into int datatype.
# Import label encoder
from sklearn import preprocessing

# label_encoder object knows how
# to understand word labels.
label_encoder = preprocessing.LabelEncoder()
obj = (df.dtypes == 'object')
for col in list(obj[obj].index):
  df[col] = label_encoder.fit_transform(df[col])

# %%
#checking the object datatype columns. Finding out if there is still any left.
 #To find the number of columns with
# dftype==object
obj = (df.dtypes == 'object')
print("Categorical variables:",len(list(obj[obj].index)))
# Out:
# Categorical variables: 0

# %%
# Filling the missing values

# %%
for col in df.columns:
  df[col] = df[col].fillna(df[col].mean())

df.isna().sum()
# Out:
#  no_of_dependents            0
#  education                   0
#  self_employed               0
#  income_annum                0
#  loan_amount                 0
#  loan_term                   0
#  cibil_score                 0
#  residential_assets_value    0
#  commercial_assets_value     0
#  luxury_assets_value         0
#  bank_asset_value            0
#  loan_status                 0
# dtype: int64

# %%
df.describe()
# Out:
#         no_of_dependents    education   self_employed   income_annum  \
# count        3699.000000  3699.000000     3699.000000   3.699000e+03
# mean            2.504731     0.503379        0.508516   5.035658e+06
# std             1.696293     0.500056        0.499995   2.796572e+06
# min             0.000000     0.000000        0.000000   2.000000e+05
# 25%             1.000000     0.000000        0.000000   2.600000e+06
# 50%             3.000000     1.000000        1.000000   5.000000e+06
# 75%             4.000000     1.000000        1.000000   7.450000e+06
# max             5.000000     1.000000        1.000000   9.900000e+06
#
#         loan_amount    loan_term   cibil_score   residential_assets_value  \
# count  3.699000e+03  3699.000000   3699.000000               3.699000e+03
# mean   1.505062e+07    10.847237    598.047154               7.379441e+06
# std    9.005056e+06     5.705923    171.989024               6.423816e+06
# ...

# %%
from sklearn.model_selection import train_test_split

X = df.drop([' loan_status'], axis=1, inplace=False)
Y = df[' loan_status']
X.shape,Y.shape

X_train, X_test, Y_train, Y_test = train_test_split(X, Y,
                                                    test_size=0.4,
                                                    random_state=1)
X_train.shape, X_test.shape, Y_train.shape, Y_test.shape
# Out:
# ((2219, 11), (1480, 11), (2219,), (1480,))

# %%
 #Check if 'loan_status' exists in the DataFrame
if ' loan_status' in df.columns:
    # If it exists, drop it
    X = df.drop([' loan_status'], axis=1)
    Y = df[' loan_status']
    X.shape, Y.shape
else:
    # Handle the case where 'loan_status' does not exist
    print("Column ' loan_status' not found in the DataFrame.")

# %%
# Random Forest Classifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import SVC
from sklearn.linear_model import LogisticRegression

from sklearn import metrics

knn = KNeighborsClassifier(n_neighbors=3)
rfc = RandomForestClassifier(n_estimators = 7,
                             criterion = 'entropy',
                             random_state =7)
svc = SVC()
lc = LogisticRegression()

# making predictions on the training set
for clf in (rfc, knn, svc,lc):
    clf.fit(X_train, Y_train)
    Y_pred = clf.predict(X_train)
    print("Accuracy score of ",
          clf.__class__.__name__,
          "=",100*metrics.accuracy_score(Y_train,
                                         Y_pred))
# Out:
# Accuracy score of  RandomForestClassifier = 99.81973862100045
# Accuracy score of  KNeighborsClassifier = 75.98017124831004
# Accuracy score of  SVC = 60.92834610184767
# Accuracy score of  LogisticRegression = 60.43262730959892

# %%
#Prediction on the test set:
# making predictions on the testing set
for clf in (rfc, knn, svc,lc):
    clf.fit(X_train, Y_train)
    Y_pred = clf.predict(X_test)
    print("Accuracy score of ",
          clf.__class__.__name__,"=",
          100*metrics.accuracy_score(Y_test,
                                     Y_pred))
# Out:
# Accuracy score of  RandomForestClassifier = 97.22972972972973
# Accuracy score of  KNeighborsClassifier = 55.60810810810811
# Accuracy score of  SVC = 62.9054054054054
# Accuracy score of  LogisticRegression = 60.878378378378386
