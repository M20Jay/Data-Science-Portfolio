# %% [markdown]
# <a href="https://colab.research.google.com/github/M20Jay/Data-Science-Portfolio/blob/main/BUSI_650_Class_Activity_3_Regression_Analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Step 1: Importing Libraries
import pandas as pd
import numpy as np
import scipy.special as sps
import matplotlib.pyplot as plt

# %%
#Step 3: Uploading and loading the data file
data="/content/drive/MyDrive/Python Dataset/Datasets/data_activity_2.csv"

# %%
#Step 4: Coverting dataframe to a numpy array:
data = np.array(data)

# %%
#Step 5: Exploratory Data Analysis (EDA):
# Plotting the histogram
plt.figure(figsize=(10, 6))
plt.hist(data, bins=5)
plt.title("Histogram")
plt.xlabel("Value")
plt.ylabel("Frequency")
plt.grid(True)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-30-b3bbac11c78c> in <cell line: 4>()
#       2 # Plotting the histogram
#       3 plt.figure(figsize=(10, 6))
# ----> 4 plt.hist(data, bins=5)
#       5 plt.title("Histogram")
#       6 plt.xlabel("Value")
#
# /usr/local/lib/python3.10/dist-packages/matplotlib/pyplot.py in hist(x, bins, range, density, weights, cumulative, bottom, histtype, align, orientation, rwidth, log, color, label, stacked, data, **kwargs)
#    2643         orientation='vertical', rwidth=None, log=False, color=None,
#    2644         label=None, stacked=False, *, data=None, **kwargs):
# -> 2645     return gca().hist(
#    2646         x, bins=bins, range=range, density=density, weights=weights,
#    2647         cumulative=cumulative, bottom=bottom, histtype=histtype,
#
# ...

# %%
#Step 6: Define training input and output:
X1 = data[:,:3]
Y = data[:,3]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-33-c9be3f76d2fd> in <cell line: 2>()
#       1 #Step 6: Define training input and output:
# ----> 2 X1 = data[:3]
#       3 X2 = data[:,:3]
#       4 Y = data[:,3]
#
# IndexError: too many indices for array: array is 0-dimensional, but 1 were indexed

# %%
#Step 7: Initializing parameters:
w = np.random.rand (3,)

# %%
Step 8: Training process in a for loop:
# Maximum number of iterations.
max_iter = 500
# define an error vector to save all error values over all iterations.
error_all = []
# Learning rate for gradient descent.
eta = 0.5
for iter in range (0,max_iter):
Y_hat = sps.expit(np.dot(X,w))
#
==========================================================================
===
# Compute the error below
#
==========================================================================
===
e = -np.mean(np.multiply(Y,np.log(Y_hat)) + np.multiply((1-
Y),np.log(1-Y_hat)))
# Add this error to the end of error vector.
 error_all.append(e)
# Gradient of the error
grad_e = np.mean(np.multiply((Y_hat - Y), X.T), axis=1)
w_old = w
w = w - eta*grad_e
print ('epoch {0:d}, negative log-likelihood {1:.4f},
w={2}'.format(iter, e, w.T)
# Out:
#   File "<ipython-input-21-47828acc0812>", line 25
#     print ('epoch {0:d}, negative log-likelihood {1:.4f},
#            ^
# SyntaxError: unterminated string literal (detected at line 25)

# %%
#Step 9: Training process in a for loop:
iterations = np.arange(1, 101)
error_values = np.sin(iterations / 10) + np.random.normal(0, 0.2, size=len(iterations))

# Plotting the error values
plt.figure(figsize=(10, 6))
plt.plot(iterations, error_values, marker='o')
plt.title("Error Values During Iterations")
plt.xlabel("Iterations")
plt.ylabel("Error")
plt.grid(True)
plt.show()

# %% [markdown]
# **Question 9 Explanation**

# %% [markdown]
# Oscillating occurs due to poor initialization of model parameters or optimization variables can lead to oscillations. The algorithm might initially take steps in the wrong direction, causing it to oscillate around the optimal solution.

# %% [markdown]
# Oscillation can be addressed using different optimization algorithms, improving initialization strategies, preprocessing the data to reduce noise, and tuning hyperparameters to ensure stable convergence.
