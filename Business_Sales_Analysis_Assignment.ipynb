# %% [markdown]
# <a href="https://colab.research.google.com/github/M20Jay/Data-Science-Portfolio/blob/main/Business_Sales_Analysis_Assignment.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Importing Libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
#load dataset
path="/content/drive/MyDrive/Python Dataset/Datasets/dataset_assignment2.csv"

# %%
data= pd.read_csv(path)

# %%
data.describe()
# Out:
#          UnitCost        Sales      Profit
# count   95.000000    95.000000  100.000000
# mean    36.477065   551.843037  473.733831
# std     41.691400   185.058741   94.232806
# min      5.248495   301.243109  259.669437
# 25%     15.600180   447.598479  402.872525
# 50%     28.403061   517.457781  479.864679
# 75%     40.106948   582.462170  529.131281
# max    243.156541  1373.154902  736.928966

# %%
data.isna().sum()
# Out:
# UnitCost    5
# Sales       5
# Profit      0
# dtype: int64

# %%
# Identifying outliers and describing them

# %%
x=data.Sales
Y=data.Profit

# %%
plt.boxplot(y)
plt.ylabel("Values")           # Label the y-axis
plt.title("Box Plot of y Values")
# Out:
# Text(0.5, 1.0, 'Box Plot of y Values')

# %%
plt.boxplot(x)
plt.ylabel("Values")           # Label the x-axis
plt.title("Box Plot of x Values")
# Out:
# Text(0.5, 1.0, 'Box Plot of x Values')

# %%
# Handling missing values in the dataset
plt.figure(figsize=(10, 5))
plt.subplot(1, 2, 1)
plt.plot(x, marker='o')
plt.xlabel("x Values")
plt.ylabel("y Values")
plt.title("Curve Before Removing Missing Values")
# Out:
# Text(0.5, 1.0, 'Curve Before Removing Missing Values')

# %%
#Removing missing values
data.dropna()
# Out:
#       UnitCost        Sales      Profit
# 0    21.854305   508.704707  486.850401
# 1    47.782144   470.099265  422.317121
# 2   189.698637  1018.352155  471.236350
# 3    31.939632   301.243109  269.303477
# 4    12.020839   478.032811  466.011972
# ..         ...          ...         ...
# 95   27.220802   418.418971  391.198170
# 96   28.522977   492.289829  463.766852
# 97   24.239346   534.115198  509.875852
# 98   30.719304  1055.338160  521.525219
# 99    9.855114   582.718325  572.863211
#
# [95 rows x 3 columns]

# %%
# Handling missing values in the dataset
plt.figure(figsize=(10, 5))
plt.subplot(1, 2, 1)
plt.plot(x, marker='o')
plt.xlabel("x Values")
plt.ylabel("y Values")
plt.title("Curve After Removing Missing Values")
# Out:
# Text(0.5, 1.0, 'Curve After Removing Missing Values')

# %%
# Correlation Analysis
correlation_matrix = data.corr()
print(correlation_matrix)
# Out:
#           UnitCost     Sales    Profit
# UnitCost  1.000000  0.583894 -0.125098
# Sales     0.583894  1.000000  0.536852
# Profit   -0.125098  0.536852  1.000000
